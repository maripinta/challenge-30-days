# %% [markdown]
# # 30 Day Chart Challenge

# %% [markdown]
# Cargar los datos

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el dataset
df = pd.read_csv("data/Predict_student_dropout_and_academic_success.csv", sep=";")
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %% [markdown]
# Tema: Comparación de ocupaciones de los padres de los estudiantes

# %%
# Contar las ocupaciones de los padres
father_occupation = df['Father\'s occupation'].value_counts().nlargest(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=father_occupation.values, y=father_occupation.index, palette='pastel')
plt.title('Top 10 Ocupaciones de los Padres de los Estudiantes')
plt.xlabel('Número de Estudiantes')
plt.ylabel('Ocupación del Padre')
plt.grid(axis='x')
plt.show()
# Out:
# /var/folders/zr/5cp0kjw90ldcs2bbgq01m31w0000gn/T/ipykernel_12290/2817165411.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=father_occupation.values, y=father_occupation.index, palette='pastel')

# %% [markdown]
# Este gráfico de barras muestra las diez ocupaciones más comunes de los padres de los estudiantes. Cada barra representa el número de estudiantes cuyo padre tiene una ocupación específica.
